# %%
# import original dataset
root_dir = '/Users/danielmartinezvillegas/Downloads/groove'
info = 'filtered_info.csv'

# %%
import pandas as pd

# %%
info_df = pd.read_csv(f'{root_dir}/{info}')
info_df.head()
# Out:
#     drummer                session                        id          style  \
# 0  drummer1  drummer1/eval_session   drummer1/eval_session/1   funk/groove1
# 1  drummer1  drummer1/eval_session  drummer1/eval_session/10  soul/groove10
# 2  drummer1  drummer1/eval_session   drummer1/eval_session/2   funk/groove2
# 3  drummer1  drummer1/eval_session   drummer1/eval_session/3   soul/groove3
# 4  drummer1  drummer1/eval_session   drummer1/eval_session/4   soul/groove4
#
#    bpm beat_type time_signature  \
# 0  138      beat            4-4
# 1  102      beat            4-4
# 2  105      beat            4-4
# 3   86      beat            4-4
# 4   80      beat            4-4
#
#                                        midi_filename  \
# 0  drummer1/eval_session/1_funk-groove1_138_beat_...
# 1  drummer1/eval_session/10_soul-groove10_102_bea...
# 2  drummer1/eval_session/2_funk-groove2_105_beat_...
# 3  drummer1/eval_session/3_soul-groove3_86_beat_4...
# 4  drummer1/eval_session/4_soul-groove4_80_beat_4...
#
#                                       audio_filename   duration split
# 0  drummer1/eval_session/1_funk-groove1_138_beat_...  27.872308  test
# 1  drummer1/eval_session/10_soul-groove10_102_bea...  37.691158  test
# 2  drummer1/eval_session/2_funk-groove2_105_beat_...  36.351218  test
# 3  drummer1/eval_session/3_soul-groove3_86_beat_4...  44.716543  test
# 4  drummer1/eval_session/4_soul-groove4_80_beat_4...  47.987500  test

# %%
import os
import numpy as np
import librosa
import librosa.display
import soundfile as sf
import mido
import matplotlib.pyplot as plt

def get_first_midi_note_time(midi_path, bpm=None):
    """
    Get the time of the first note in a MIDI file
    
    Args:
        midi_path: Path to the MIDI file
        bpm: Optional beats per minute to override the MIDI file's tempo
        
    Returns:
        first_note_time: Time of first note in seconds
    """
    print(f"Analyzing MIDI file: {midi_path}")
    
    try:
        # Load the MIDI file
        midi = mido.MidiFile(midi_path)
        
        first_note_time = None
        
        # If BPM is provided, calculate tempo in microseconds per beat
        if bpm is not None:
            tempo = int(60000000 / bpm)
            print(f"Using provided BPM: {bpm} (tempo: {tempo} μs/beat)")
        else:
            # Default tempo (microseconds per beat, equivalent to 120 BPM)
            tempo = 500000
            
            # Look for tempo information in the MIDI file
            for track in midi.tracks:
                for msg in track:
                    if msg.type == 'set_tempo':
                        tempo = msg.tempo
                        print(f"Found tempo in MIDI: {60000000 / tempo:.1f} BPM")
                        break
        
        # Find first note event
        for track in midi.tracks:
            cumulative_time = 0  # in ticks
            
            # Process each message in the track
            for msg in track:
                cumulative_time += msg.time
                
                # Convert ticks to seconds
                seconds = mido.tick2second(cumulative_time, midi.ticks_per_beat, tempo)
                
                # Look for note_on events with velocity > 0
                if msg.type == 'note_on' and msg.velocity > 0:
                    if first_note_time is None or seconds < first_note_time:
                        first_note_time = seconds
        
        if first_note_time is not None:
            print(f"First MIDI note event at: {first_note_time:.3f} seconds")
            return first_note_time
        else:
            print("No note events found in MIDI file.")
            return None
            
    except Exception as e:
        print(f"Error reading MIDI file: {e}")
        return None

def get_first_wav_onset(wav_path, plot=False, method='fixed', sensitivity=0.2):
    """
    Get the time of the first significant onset using a consistent method
    
    Args:
        wav_path: Path to the WAV file
        plot: Whether to generate visualization plots
        method: Detection method ('fixed', 'energy', or 'percussion')
        sensitivity: Lower values make detection more sensitive (0.1-0.3 recommended)
        
    Returns:
        first_onset_time: Time of first significant onset in seconds
    """
    print(f"Analyzing WAV file: {wav_path} using '{method}' method (sensitivity: {sensitivity})")
    
    # Load the audio file
    y, sr = librosa.load(wav_path, sr=None)
    first_onset_frame = None
    
    # Choose a specific detection method and stick with it
    if method == 'energy':
        # Energy-based detection
        rms = librosa.feature.rms(y=y)[0]
        # Find the first frame where RMS exceeds a threshold
        threshold = sensitivity * np.max(rms)
        for i, energy in enumerate(rms):
            if energy > threshold:
                hop_length = 512  # Standard hop length for RMS
                first_onset_frame = i
                print(f"Energy-based detection found onset at frame {i}")
                break
                
    elif method == 'percussion':
        # Percussion-specific detection
        y_perc = librosa.effects.harmonic(y=y)
        onset_env_perc = librosa.onset.onset_strength(y=y_perc, sr=sr)
        onset_frames = librosa.onset.onset_detect(
            onset_envelope=onset_env_perc, 
            sr=sr, 
            delta=sensitivity
        )
        if len(onset_frames) > 0:
            first_onset_frame = onset_frames[0]
            print(f"Percussion-specific detection found onset at frame {first_onset_frame}")
            
    else:  # 'fixed' method (default)
        # Standard onset detection with consistent parameters
        onset_env = librosa.onset.onset_strength(y=y, sr=sr)
        onset_frames = librosa.onset.onset_detect(
            onset_envelope=onset_env, 
            sr=sr, 
            delta=sensitivity,
            wait=1
        )
        if len(onset_frames) > 0:
            first_onset_frame = onset_frames[0]
            print(f"Fixed onset detection found onset at frame {first_onset_frame}")
    
    # If no onset detected, try a more sensitive approach
    if first_onset_frame is None and method == 'fixed':
        onset_frames = librosa.onset.onset_detect(
            y=y, 
            sr=sr, 
            delta=sensitivity/2,  # More sensitive
            wait=1
        )
        if len(onset_frames) > 0:
            first_onset_frame = onset_frames[0]
            print(f"More sensitive detection found onset at frame {first_onset_frame}")
    
    # If still no onset detected
    if first_onset_frame is None:
        print("Warning: No significant audio onset could be detected.")
        return None
    
    # Convert frame to time
    first_onset_time = librosa.frames_to_time(first_onset_frame, sr=sr)
    # If frames_to_time returns an array, take first element
    if isinstance(first_onset_time, np.ndarray):
        first_onset_time = first_onset_time[0]
    
    print(f"First significant audio onset at: {first_onset_time:.3f} seconds")
    
    # Optional: Generate plot of the onset detection
    if plot:
        plt.figure(figsize=(12, 6))
        
        # Plot waveform
        plt.subplot(2, 1, 1)
        librosa.display.waveshow(y, sr=sr)
        plt.axvline(x=first_onset_time, color='r', linestyle='--', label='Detected Onset')
        plt.title('Waveform with Detected Onset')
        plt.legend()
        
        # Plot onset strength
        plt.subplot(2, 1, 2)
        onset_env = librosa.onset.onset_strength(y=y, sr=sr)
        frames = range(len(onset_env))
        times = librosa.frames_to_time(frames, sr=sr)
        plt.plot(times, onset_env)
        plt.axvline(x=first_onset_time, color='r', linestyle='--', label='Detected Onset')
        plt.title('Onset Strength Function')
        plt.legend()
        
        plt.tight_layout()
        
        # Save the plot
        plot_path = os.path.splitext(wav_path)[0] + '_onset_detection.png'
        plt.savefig(plot_path)
        plt.close()
        print(f"Saved onset detection plot to {plot_path}")
    
    return first_onset_time

def trim_wav_file(wav_path, output_path, trim_seconds):
    """
    Trim the beginning of a WAV file by the specified number of seconds
    
    Args:
        wav_path: Path to the input WAV file
        output_path: Path to save the trimmed WAV file
        trim_seconds: Number of seconds to trim from the beginning
        
    Returns:
        success: Boolean indicating success or failure
    """
    print(f"Trimming {trim_seconds:.3f} seconds from the beginning of {os.path.basename(wav_path)}")
    
    # Load the audio file
    y, sr = librosa.load(wav_path, sr=None)  # Use original sample rate
    
    # Calculate the number of samples to trim
    trim_samples = int(trim_seconds * sr)
    
    # Ensure we don't try to trim more samples than we have
    if trim_samples >= len(y):
        print(f"Error: Cannot trim {trim_seconds:.3f}s as the file is only {len(y)/sr:.3f}s long")
        return False
    
    # Ensure we don't trim a negative number of samples
    if trim_samples < 0:
        print(f"Error: Cannot trim negative time ({trim_seconds:.3f}s)")
        return False
    
    # Trim the audio
    y_trimmed = y[trim_samples:]
    
    # Save the trimmed audio
    sf.write(output_path, y_trimmed, sr)
    print(f"Saved trimmed file to {output_path}")
    
    return True

def align_wav_to_midi(midi_path, wav_path, output_dir=None, plot=False, bpm=None, 
                     detection_method='fixed', detection_sensitivity=0.2):
    """
    Precisely align a WAV file to a MIDI file by matching first events
    
    Args:
        midi_path: Path to the MIDI file
        wav_path: Path to the WAV file
        output_dir: Directory to save the aligned WAV file
        plot: Whether to generate visualization plots
        bpm: Optional beats per minute to override the MIDI file's tempo
        detection_method: Method for onset detection ('fixed', 'energy', or 'percussion')
        detection_sensitivity: Sensitivity for onset detection (lower = more sensitive)
        
    Returns:
        output_path: Path to the aligned WAV file
        trim_amount: Amount of time trimmed in seconds
        alignment_info: Dictionary with detailed alignment information
    """
    print("\n==== Precise MIDI-WAV Alignment ====")
    if bpm is not None:
        print(f"Using custom BPM: {bpm}")
    print(f"Using detection method: {detection_method} (sensitivity: {detection_sensitivity})")
    
    # Store alignment info for verification
    alignment_info = {
        'original_wav_path': wav_path,
        'midi_path': midi_path,
        'bpm': bpm,
        'detection_method': detection_method,
        'detection_sensitivity': detection_sensitivity
    }
    
    # Set up output directory
    if output_dir is None:
        output_dir = os.path.dirname(wav_path)
    os.makedirs(output_dir, exist_ok=True)
    
    # Get base filename
    base_name = os.path.splitext(os.path.basename(wav_path))[0]
    output_path = os.path.join(output_dir, f"{base_name}.wav")
    
    # Step 1: Get first MIDI note time
    midi_note_time = get_first_midi_note_time(midi_path, bpm)
    if midi_note_time is None:
        print("Could not determine first MIDI note time. Aborting.")
        return None, 0, None
    
    # Step 2: Get first WAV onset time using the specified method
    wav_onset_time = get_first_wav_onset(
        wav_path, 
        plot=plot, 
        method=detection_method, 
        sensitivity=detection_sensitivity
    )
    if wav_onset_time is None:
        print("Could not determine first WAV onset time. Aborting.")
        return None, 0, None
    
    # Step 3: Calculate precise trim amount
    # We want: wav_onset_time - trim_amount = midi_note_time
    # Therefore: trim_amount = wav_onset_time - midi_note_time
    trim_amount = wav_onset_time - midi_note_time
    
    # Store in alignment info
    alignment_info['midi_note_time'] = midi_note_time
    alignment_info['wav_onset_time'] = wav_onset_time
    alignment_info['trim_amount'] = trim_amount
    
    # Only trim if the WAV onset is after the MIDI note (positive trim amount)
    if trim_amount <= 0:
        print(f"WAV file already starts {abs(trim_amount):.3f}s before MIDI file.")
        print(f"No trimming needed as WAV onset precedes MIDI note.")
        
        # Copy the file instead of trimming
        import shutil
        shutil.copy2(wav_path, output_path)
        print(f"Copied original file to {output_path}")
        
        alignment_info['action'] = 'copied'
        return output_path, 0, alignment_info
    
    # Step 4: Trim the WAV file by the precise amount
    success = trim_wav_file(wav_path, output_path, trim_amount)
    
    if success:
        print(f"\n✅ Successfully aligned WAV to MIDI")
        print(f"   WAV onset was at {wav_onset_time:.3f}s, MIDI note at {midi_note_time:.3f}s")
        print(f"   Trimmed exactly {trim_amount:.3f}s from the beginning")
        
        alignment_info['action'] = 'trimmed'
        alignment_info['output_path'] = output_path
                
        # Verify the alignment
        if plot:
            verify_alignment_fixed(midi_path, output_path, trim_amount, bpm, alignment_info)
        
        return output_path, trim_amount, alignment_info
    else:
        print(f"\n❌ Failed to align WAV to MIDI")
        return None, 0, None

def verify_alignment_fixed(midi_path, aligned_wav_path, trim_amount, bpm=None, alignment_info=None):
    """
    Verify alignment using the known trim amount rather than re-detecting onsets
    
    Args:
        midi_path: Path to the MIDI file
        aligned_wav_path: Path to the aligned WAV file
        trim_amount: The amount that was trimmed from the original WAV
        bpm: Optional beats per minute to override the MIDI file's tempo
        alignment_info: Dictionary with detailed alignment information
    """
    print("\n==== Verifying Alignment ====")
    
    # Get first MIDI note time again (should be the same)
    midi_note_time = get_first_midi_note_time(midi_path, bpm)
    if midi_note_time is None:
        print("Could not verify MIDI timing. Skipping verification.")
        return
    
    # Calculate where the WAV onset should be in the trimmed file
    # In the aligned file, the onset should be at the same time as the midi note
    expected_wav_onset = midi_note_time
    
    print("Verification based on fixed trim amount:")
    print(f"  Original WAV onset time: {alignment_info['wav_onset_time']:.3f}s")
    print(f"  MIDI first note time: {midi_note_time:.3f}s")
    print(f"  Applied trim amount: {trim_amount:.3f}s")
    print(f"  Expected WAV onset now at: {expected_wav_onset:.3f}s")
    
    # Optional: also do a detection-based verification as a sanity check
    # But don't rely on it for the primary verification
    detection_method = alignment_info.get('detection_method', 'fixed')
    detection_sensitivity = alignment_info.get('detection_sensitivity', 0.2)
    
    print("\nAdditional verification by re-detecting onset (for information only):")
    detected_onset = get_first_wav_onset(
        aligned_wav_path, 
        method=detection_method, 
        sensitivity=detection_sensitivity
    )
    
    if detected_onset is not None:
        # Calculate offset between expected and detected onset
        offset = detected_onset - expected_wav_onset
        print(f"  Re-detected onset at: {detected_onset:.3f}s")
        print(f"  Offset from expected: {offset:.3f}s")
        
        # Check if within tolerance
        tolerance = 0.05  # 50 milliseconds
        if abs(offset) <= tolerance:
            print(f"✅ Re-detection confirms good alignment (offset within {tolerance*1000:.0f}ms)")
        else:
            print(f"⚠️ Re-detection shows different onset point (offset: {offset*1000:.0f}ms)")
            print(f"   This is expected due to detection inconsistency, but fixed trim verification confirms proper alignment")
    else:
        print("  Could not re-detect onset in aligned file")
    
    print("\n✅ Alignment confirmed by fixed trim amount method")
    
    # Optional: Create a visualization to compare the two files
    if True:  # Set to False to disable visualization
        # Load both audio files
        y_midi_file, sr_midi = librosa.load(midi_path, sr=None) if midi_path.endswith('.wav') else (None, None)
        y_aligned, sr_aligned = librosa.load(aligned_wav_path, sr=None)
        
        # If MIDI file is not a WAV, we can't visualize it directly
        if y_midi_file is None:
            print("MIDI file is not a WAV file. Skipping waveform comparison.")
            return
        
        # Create visualization
        plt.figure(figsize=(12, 8))
        
        # Plot MIDI waveform (or corresponding audio)
        plt.subplot(2, 1, 1)
        librosa.display.waveshow(y_midi_file, sr=sr_midi)
        plt.axvline(x=midi_note_time, color='r', linestyle='--', label='MIDI First Note')
        plt.title('MIDI Audio Waveform')
        plt.legend()
        
        # Plot aligned WAV waveform
        plt.subplot(2, 1, 2)
        librosa.display.waveshow(y_aligned, sr=sr_aligned)
        plt.axvline(x=expected_wav_onset, color='r', linestyle='--', label='Expected Onset Position')
        if detected_onset is not None:
            plt.axvline(x=detected_onset, color='g', linestyle=':', label='Re-detected Onset')
        plt.title('Aligned WAV Waveform')
        plt.legend()
        
        plt.tight_layout()
        
        # Save the visualization
        viz_path = os.path.splitext(aligned_wav_path)[0] + '_alignment_verification.png'
        plt.savefig(viz_path)
        plt.close()
        print(f"Saved alignment verification visualization to {viz_path}")

def verify_alignment(midi_path, aligned_wav_path, bpm=None):
    """
    Legacy verification function - kept for compatibility
    Uses the potentially inconsistent onset detection for verification
    
    Args:
        midi_path: Path to the MIDI file
        aligned_wav_path: Path to the aligned WAV file
        bpm: Optional beats per minute
    """
    print("\n==== Legacy Verification (Using Inconsistent Detection) ====")
    print("⚠️ This verification method is kept for compatibility but is not reliable.")
    print("   It uses onset re-detection which can give inconsistent results.")
    print("   Please use the fixed verification method instead.\n")
    
    # Get first MIDI note time again
    midi_note_time = get_first_midi_note_time(midi_path, bpm)
    
    # Get first onset time in aligned WAV - this is where inconsistencies occur
    aligned_onset_time = get_first_wav_onset(aligned_wav_path)
    
    if midi_note_time is None or aligned_onset_time is None:
        print("Could not verify alignment due to detection failure")
        return
    
    # Calculate offset
    offset = aligned_onset_time - midi_note_time
    print(f"Alignment offset: {offset:.3f} seconds")
    
    # Check if within tolerance
    tolerance = 0.05  # 50 milliseconds
    if abs(offset) <= tolerance:
        print(f"✅ Files are well-aligned! (offset within {tolerance*1000:.0f}ms)")
    else:
        print(f"⚠️ Files may not be perfectly aligned (offset: {offset*1000:.0f}ms)")
        print(f"   This could be due to onset detection differences between runs")
        print(f"   Consider using the fixed verification method instead")

def copy_midi_to_new_dir(aligned_wav_path, midi_path):
    """
    Copy the MIDI file to the same directory as the aligned WAV file
    
    Args:
        aligned_wav_path: Path to the aligned WAV file
        midi_path: Path to the MIDI file
    """
    # Get the directory of the aligned WAV file
    new_dir = os.path.dirname(aligned_wav_path)
    
    # Get the filename of the MIDI file
    midi_filename = os.path.basename(midi_path)
    
    # Create the new path for the MIDI file
    new_midi_path = os.path.join(new_dir, midi_filename)
    
    # Copy the MIDI file to the new directory
    import shutil
    shutil.copy2(midi_path, new_midi_path)
    print(f"Copied MIDI file to {new_midi_path}")

def batch_align(csv_file, base_dir=None, output_dir=None, detection_method='fixed', detection_sensitivity=0.2):
    """
    Align multiple WAV files to MIDI files based on a CSV file
    
    CSV format:
    midi_path,wav_path,bpm
    
    Args:
        csv_file: Path to the CSV file
        base_dir: Base directory for relative paths in the CSV
        output_dir: Directory to save the aligned WAV files
        detection_method: Method for onset detection
        detection_sensitivity: Sensitivity for onset detection
    """
    import csv
    
    print(f"Batch aligning files from {csv_file}")
    
    with open(csv_file, 'r') as f:
        reader = csv.reader(f)
        header = next(reader)  # Skip header
        
        for i, row in enumerate(reader):
            print(f"\nProcessing row {i+1}:")
            
            # Parse the row
            if len(row) >= 3:
                midi_path, wav_path, bpm = row[0], row[1], float(row[2])
            else:
                print(f"Error: Row {i+1} does not have enough columns. Skipping.")
                continue
            
            # Handle relative paths
            if base_dir and not os.path.isabs(midi_path):
                midi_path = os.path.join(base_dir, midi_path)
            if base_dir and not os.path.isabs(wav_path):
                wav_path = os.path.join(base_dir, wav_path)
            
            # Set output directory for this file
            if output_dir:
                file_output_dir = os.path.join(output_dir, os.path.splitext(os.path.basename(wav_path))[0])
            else:
                file_output_dir = os.path.dirname(wav_path)
            
            # Align the file
            align_wav_to_midi(
                midi_path=midi_path,
                wav_path=wav_path,
                output_dir=file_output_dir,
                plot=True,
                bpm=bpm,
                detection_method=detection_method,
                detection_sensitivity=detection_sensitivity
            )

# %%
def copy_midi_to_new_dir(aligned_wav_path, midi_path):
    midi_output_path = os.path.join(os.path.dirname(aligned_wav_path), os.path.basename(midi_path))

    if not os.path.exists(midi_output_path):
        os.system(f"cp {midi_path} {midi_output_path}")
        print(f"Copied MIDI file to {midi_output_path}")
    else:
        print(f"MIDI file already exists at {midi_output_path}")

# %%
"/".join(info_df.iloc[0]['audio_filename'].split("/")[:-1])
# Out:
# 'drummer1/eval_session'

# %%
info_df.shape[0]
# Out:
# 1090

# %%
# Define the root directory for aligned files
output_dir_root = '/Users/danielmartinezvillegas/Downloads/groove-aligned'

# Iterate through the first 5 rows of the DataFrame
for i in range(info_df.shape[0]):
    midi_file = f"{root_dir}/{info_df.iloc[i]['midi_filename']}"
    wav_file = f"{root_dir}/{info_df.iloc[i]['audio_filename']}"
    output_clean = "/".join(info_df.iloc[i]['audio_filename'].split("/")[:-1])
    output_dir = f"{output_dir_root}/{output_clean}"
    
    # Get BPM from the DataFrame
    bpm = int(info_df.iloc[i]["bpm"])
    print(f"\nProcessing row {i + 1}:")
    print(midi_file, wav_file, output_dir, bpm)
    
    aligned_wav, trim_amount, alignment_info = align_wav_to_midi(
        midi_path=midi_file,
        wav_path=wav_file, 
        output_dir=output_dir,
        bpm=bpm,
        detection_method='fixed', 
        detection_sensitivity=0.2 
    )
    os.system(f"cp {midi_file} {output_dir_root}/{output_clean}")
# Out:
# Processing row 1:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/1_funk-groove1_138_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/1_funk-groove1_138_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session 138
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 138
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/1_funk-groove1_138_beat_4-4.mid
# Using provided BPM: 138 (tempo: 434782 μs/beat)
# First MIDI note event at: 0.003 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/1_funk-groove1_138_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 3
# First significant audio onset at: 0.035 seconds
# Trimming 0.032 seconds from the beginning of 1_funk-groove1_138_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session/1_funk-groove1_138_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.035s, MIDI note at 0.003s
#    Trimmed exactly 0.032s from the beginning
#
# Processing row 2:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/10_soul-groove10_102_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/10_soul-groove10_102_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session 102
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 102
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/10_soul-groove10_102_beat_4-4.mid
# Using provided BPM: 102 (tempo: 588235 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/10_soul-groove10_102_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 49
# First significant audio onset at: 0.569 seconds
# Trimming 0.569 seconds from the beginning of 10_soul-groove10_102_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session/10_soul-groove10_102_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.569s, MIDI note at 0.000s
#    Trimmed exactly 0.569s from the beginning
#
# Processing row 3:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/2_funk-groove2_105_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/2_funk-groove2_105_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session 105
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 105
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/2_funk-groove2_105_beat_4-4.mid
# Using provided BPM: 105 (tempo: 571428 μs/beat)
# First MIDI note event at: 0.024 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/2_funk-groove2_105_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 3
# First significant audio onset at: 0.035 seconds
# Trimming 0.011 seconds from the beginning of 2_funk-groove2_105_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session/2_funk-groove2_105_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.035s, MIDI note at 0.024s
#    Trimmed exactly 0.011s from the beginning
#
# Processing row 4:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/3_soul-groove3_86_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/3_soul-groove3_86_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session 86
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 86
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/3_soul-groove3_86_beat_4-4.mid
# Using provided BPM: 86 (tempo: 697674 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/3_soul-groove3_86_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 32
# First significant audio onset at: 0.372 seconds
# Trimming 0.372 seconds from the beginning of 3_soul-groove3_86_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session/3_soul-groove3_86_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.372s, MIDI note at 0.000s
#    Trimmed exactly 0.372s from the beginning
#
# Processing row 5:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/4_soul-groove4_80_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/4_soul-groove4_80_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session 80
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 80
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/4_soul-groove4_80_beat_4-4.mid
# Using provided BPM: 80 (tempo: 750000 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/4_soul-groove4_80_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 33
# First significant audio onset at: 0.383 seconds
# Trimming 0.383 seconds from the beginning of 4_soul-groove4_80_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session/4_soul-groove4_80_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.383s, MIDI note at 0.000s
#    Trimmed exactly 0.383s from the beginning
#
# Processing row 6:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/5_funk-groove5_84_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/5_funk-groove5_84_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session 84
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 84
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/5_funk-groove5_84_beat_4-4.mid
# Using provided BPM: 84 (tempo: 714285 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/5_funk-groove5_84_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 50
# First significant audio onset at: 0.580 seconds
# Trimming 0.580 seconds from the beginning of 5_funk-groove5_84_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session/5_funk-groove5_84_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.580s, MIDI note at 0.000s
#    Trimmed exactly 0.580s from the beginning
#
# Processing row 7:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/6_hiphop-groove6_87_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/6_hiphop-groove6_87_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session 87
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 87
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/6_hiphop-groove6_87_beat_4-4.mid
# Using provided BPM: 87 (tempo: 689655 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/6_hiphop-groove6_87_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 31
# First significant audio onset at: 0.360 seconds
# Trimming 0.360 seconds from the beginning of 6_hiphop-groove6_87_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session/6_hiphop-groove6_87_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.360s, MIDI note at 0.000s
#    Trimmed exactly 0.360s from the beginning
#
# Processing row 8:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/7_pop-groove7_138_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/7_pop-groove7_138_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session 138
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 138
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/7_pop-groove7_138_beat_4-4.mid
# Using provided BPM: 138 (tempo: 434782 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/7_pop-groove7_138_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 19
# First significant audio onset at: 0.221 seconds
# Trimming 0.221 seconds from the beginning of 7_pop-groove7_138_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session/7_pop-groove7_138_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.221s, MIDI note at 0.000s
#    Trimmed exactly 0.221s from the beginning
#
# Processing row 9:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/8_rock-groove8_65_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/8_rock-groove8_65_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session 65
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 65
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/8_rock-groove8_65_beat_4-4.mid
# Using provided BPM: 65 (tempo: 923076 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/8_rock-groove8_65_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 42
# First significant audio onset at: 0.488 seconds
# Trimming 0.488 seconds from the beginning of 8_rock-groove8_65_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session/8_rock-groove8_65_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.488s, MIDI note at 0.000s
#    Trimmed exactly 0.488s from the beginning
#
# Processing row 10:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/9_soul-groove9_105_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/9_soul-groove9_105_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session 105
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 105
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/9_soul-groove9_105_beat_4-4.mid
# Using provided BPM: 105 (tempo: 571428 μs/beat)
# First MIDI note event at: 0.005 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/eval_session/9_soul-groove9_105_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 27
# First significant audio onset at: 0.313 seconds
# Trimming 0.309 seconds from the beginning of 9_soul-groove9_105_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/eval_session/9_soul-groove9_105_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.313s, MIDI note at 0.005s
#    Trimmed exactly 0.309s from the beginning
#
# Processing row 11:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/1_funk_80_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/1_funk_80_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 80
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 80
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/1_funk_80_beat_4-4.mid
# Using provided BPM: 80 (tempo: 750000 μs/beat)
# First MIDI note event at: 2.116 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/1_funk_80_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 196
# First significant audio onset at: 2.276 seconds
# Trimming 0.160 seconds from the beginning of 1_funk_80_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/1_funk_80_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 2.276s, MIDI note at 2.116s
#    Trimmed exactly 0.160s from the beginning
#
# Processing row 12:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/10_jazz-funk_116_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/10_jazz-funk_116_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 116
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 116
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/10_jazz-funk_116_fill_4-4.mid
# Using provided BPM: 116 (tempo: 517241 μs/beat)
# First MIDI note event at: 0.006 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/10_jazz-funk_116_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 3
# First significant audio onset at: 0.035 seconds
# Trimming 0.028 seconds from the beginning of 10_jazz-funk_116_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/10_jazz-funk_116_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.035s, MIDI note at 0.006s
#    Trimmed exactly 0.028s from the beginning
#
# Processing row 13:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/100_neworleans-secondline_94_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/100_neworleans-secondline_94_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 94
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 94
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/100_neworleans-secondline_94_beat_4-4.mid
# Using provided BPM: 94 (tempo: 638297 μs/beat)
# First MIDI note event at: 1.121 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/100_neworleans-secondline_94_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 97
# First significant audio onset at: 1.126 seconds
# Trimming 0.005 seconds from the beginning of 100_neworleans-secondline_94_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/100_neworleans-secondline_94_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 1.126s, MIDI note at 1.121s
#    Trimmed exactly 0.005s from the beginning
#
# Processing row 14:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/101_dance-disco_120_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/101_dance-disco_120_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 120
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 120
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/101_dance-disco_120_beat_4-4.mid
# Using provided BPM: 120 (tempo: 500000 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/101_dance-disco_120_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 43
# First significant audio onset at: 0.499 seconds
# Trimming 0.499 seconds from the beginning of 101_dance-disco_120_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/101_dance-disco_120_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.499s, MIDI note at 0.000s
#    Trimmed exactly 0.499s from the beginning
#
# Processing row 15:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/102_funk_95_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/102_funk_95_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/102_funk_95_beat_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 1.533 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/102_funk_95_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 149
# First significant audio onset at: 1.730 seconds
# Trimming 0.197 seconds from the beginning of 102_funk_95_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/102_funk_95_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 1.730s, MIDI note at 1.533s
#    Trimmed exactly 0.197s from the beginning
#
# Processing row 16:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/103_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/103_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/103_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 0.064 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/103_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 14
# First significant audio onset at: 0.163 seconds
# Trimming 0.098 seconds from the beginning of 103_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/103_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.163s, MIDI note at 0.064s
#    Trimmed exactly 0.098s from the beginning
#
# Processing row 17:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/104_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/104_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/104_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/104_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 42
# First significant audio onset at: 0.488 seconds
# Trimming 0.488 seconds from the beginning of 104_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/104_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.488s, MIDI note at 0.000s
#    Trimmed exactly 0.488s from the beginning
#
# Processing row 18:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/105_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/105_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/105_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 1.947 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/105_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 170
# First significant audio onset at: 1.974 seconds
# Trimming 0.026 seconds from the beginning of 105_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/105_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 1.974s, MIDI note at 1.947s
#    Trimmed exactly 0.026s from the beginning
#
# Processing row 19:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/106_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/106_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/106_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 2.399 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/106_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 222
# First significant audio onset at: 2.577 seconds
# Trimming 0.179 seconds from the beginning of 106_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/106_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 2.577s, MIDI note at 2.399s
#    Trimmed exactly 0.179s from the beginning
#
# Processing row 20:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/107_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/107_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/107_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/107_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 26
# First significant audio onset at: 0.302 seconds
# Trimming 0.302 seconds from the beginning of 107_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/107_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.302s, MIDI note at 0.000s
#    Trimmed exactly 0.302s from the beginning
#
# Processing row 21:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/108_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/108_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/108_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 0.008 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/108_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 3
# First significant audio onset at: 0.035 seconds
# Trimming 0.027 seconds from the beginning of 108_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/108_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.035s, MIDI note at 0.008s
#    Trimmed exactly 0.027s from the beginning
#
# Processing row 22:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/109_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/109_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/109_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 2.375 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/109_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 216
# First significant audio onset at: 2.508 seconds
# Trimming 0.133 seconds from the beginning of 109_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/109_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 2.508s, MIDI note at 2.375s
#    Trimmed exactly 0.133s from the beginning
#
# Processing row 23:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/11_jazz-funk_116_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/11_jazz-funk_116_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 116
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 116
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/11_jazz-funk_116_fill_4-4.mid
# Using provided BPM: 116 (tempo: 517241 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/11_jazz-funk_116_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 33
# First significant audio onset at: 0.383 seconds
# Trimming 0.383 seconds from the beginning of 11_jazz-funk_116_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/11_jazz-funk_116_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.383s, MIDI note at 0.000s
#    Trimmed exactly 0.383s from the beginning
#
# Processing row 24:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/110_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/110_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/110_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 2.374 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/110_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 218
# First significant audio onset at: 2.531 seconds
# Trimming 0.157 seconds from the beginning of 110_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/110_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 2.531s, MIDI note at 2.374s
#    Trimmed exactly 0.157s from the beginning
#
# Processing row 25:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/111_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/111_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/111_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/111_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 23
# First significant audio onset at: 0.267 seconds
# Trimming 0.267 seconds from the beginning of 111_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/111_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.267s, MIDI note at 0.000s
#    Trimmed exactly 0.267s from the beginning
#
# Processing row 26:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/112_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/112_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/112_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 2.353 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/112_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 204
# First significant audio onset at: 2.368 seconds
# Trimming 0.016 seconds from the beginning of 112_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/112_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 2.368s, MIDI note at 2.353s
#    Trimmed exactly 0.016s from the beginning
#
# Processing row 27:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/113_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/113_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/113_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 2.120 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/113_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 203
# First significant audio onset at: 2.357 seconds
# Trimming 0.237 seconds from the beginning of 113_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/113_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 2.357s, MIDI note at 2.120s
#    Trimmed exactly 0.237s from the beginning
#
# Processing row 28:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/114_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/114_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/114_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 0.022 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/114_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 3
# First significant audio onset at: 0.035 seconds
# Trimming 0.012 seconds from the beginning of 114_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/114_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.035s, MIDI note at 0.022s
#    Trimmed exactly 0.012s from the beginning
#
# Processing row 29:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/115_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/115_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/115_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 0.025 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/115_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 3
# First significant audio onset at: 0.035 seconds
# Trimming 0.010 seconds from the beginning of 115_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/115_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.035s, MIDI note at 0.025s
#    Trimmed exactly 0.010s from the beginning
#
# Processing row 30:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/116_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/116_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/116_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/116_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 3
# First significant audio onset at: 0.035 seconds
# Trimming 0.035 seconds from the beginning of 116_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/116_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.035s, MIDI note at 0.000s
#    Trimmed exactly 0.035s from the beginning
#
# Processing row 31:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/117_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/117_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/117_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 0.003 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/117_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 40
# First significant audio onset at: 0.464 seconds
# Trimming 0.462 seconds from the beginning of 117_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/117_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.464s, MIDI note at 0.003s
#    Trimmed exactly 0.462s from the beginning
#
# Processing row 32:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/118_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/118_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/118_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/118_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 14
# First significant audio onset at: 0.163 seconds
# Trimming 0.163 seconds from the beginning of 118_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/118_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.163s, MIDI note at 0.000s
#    Trimmed exactly 0.163s from the beginning
#
# Processing row 33:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/119_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/119_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/119_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 0.150 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/119_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 13
# First significant audio onset at: 0.151 seconds
# Trimming 0.001 seconds from the beginning of 119_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/119_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.151s, MIDI note at 0.150s
#    Trimmed exactly 0.001s from the beginning
#
# Processing row 34:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/12_jazz-funk_116_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/12_jazz-funk_116_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 116
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 116
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/12_jazz-funk_116_fill_4-4.mid
# Using provided BPM: 116 (tempo: 517241 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/12_jazz-funk_116_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 23
# First significant audio onset at: 0.267 seconds
# Trimming 0.267 seconds from the beginning of 12_jazz-funk_116_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/12_jazz-funk_116_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.267s, MIDI note at 0.000s
#    Trimmed exactly 0.267s from the beginning
#
# Processing row 35:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/120_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/120_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/120_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 0.301 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/120_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 27
# First significant audio onset at: 0.313 seconds
# Trimming 0.012 seconds from the beginning of 120_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/120_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.313s, MIDI note at 0.301s
#    Trimmed exactly 0.012s from the beginning
#
# Processing row 36:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/121_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/121_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/121_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/121_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 80
# First significant audio onset at: 0.929 seconds
# Trimming 0.929 seconds from the beginning of 121_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/121_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.929s, MIDI note at 0.000s
#    Trimmed exactly 0.929s from the beginning
#
# Processing row 37:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/122_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/122_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/122_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/122_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 46
# First significant audio onset at: 0.534 seconds
# Trimming 0.534 seconds from the beginning of 122_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/122_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.534s, MIDI note at 0.000s
#    Trimmed exactly 0.534s from the beginning
#
# Processing row 38:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/123_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/123_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/123_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/123_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 53
# First significant audio onset at: 0.615 seconds
# Trimming 0.615 seconds from the beginning of 123_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/123_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.615s, MIDI note at 0.000s
#    Trimmed exactly 0.615s from the beginning
#
# Processing row 39:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/124_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/124_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/124_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/124_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 57
# First significant audio onset at: 0.662 seconds
# Trimming 0.662 seconds from the beginning of 124_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/124_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.662s, MIDI note at 0.000s
#    Trimmed exactly 0.662s from the beginning
#
# Processing row 40:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/125_funk_95_fill_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/125_funk_95_fill_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 95
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 95
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/125_funk_95_fill_4-4.mid
# Using provided BPM: 95 (tempo: 631578 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/125_funk_95_fill_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 43
# First significant audio onset at: 0.499 seconds
# Trimming 0.499 seconds from the beginning of 125_funk_95_fill_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/125_funk_95_fill_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.499s, MIDI note at 0.000s
#    Trimmed exactly 0.499s from the beginning
#
# Processing row 41:
# /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/126_funk-fast_125_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/126_funk-fast_125_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1 125
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 125
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/126_funk-fast_125_beat_4-4.mid
# Using provided BPM: 125 (tempo: 480000 μs/beat)
# First MIDI note event at: 0.467 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer1/session1/126_funk-fast_125_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 83
# First significant audio onset at: 0.964 seconds
# Trimming 0.497 seconds from the beginning of 126_funk-fast_125_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer1/session1/126_funk-fast_125_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.964s, MIDI note at 0.467s
#    Trimmed exactly 0.497s from the beginning
#
# Processing row 42:
# ...
#
# Processing row 1077:
# /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/24_rock_90_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/24_rock_90_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1 90
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 90
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/24_rock_90_beat_4-4.mid
# Using provided BPM: 90 (tempo: 666666 μs/beat)
# First MIDI note event at: 0.024 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/24_rock_90_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 3
# First significant audio onset at: 0.035 seconds
# Trimming 0.011 seconds from the beginning of 24_rock_90_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1/24_rock_90_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.035s, MIDI note at 0.024s
#    Trimmed exactly 0.011s from the beginning
#
# Processing row 1078:
# /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/25_rock_90_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/25_rock_90_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1 90
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 90
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/25_rock_90_beat_4-4.mid
# Using provided BPM: 90 (tempo: 666666 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/25_rock_90_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 58
# First significant audio onset at: 0.673 seconds
# Trimming 0.673 seconds from the beginning of 25_rock_90_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1/25_rock_90_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.673s, MIDI note at 0.000s
#    Trimmed exactly 0.673s from the beginning
#
# Processing row 1079:
# /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/26_rock_90_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/26_rock_90_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1 90
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 90
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/26_rock_90_beat_4-4.mid
# Using provided BPM: 90 (tempo: 666666 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/26_rock_90_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 29
# First significant audio onset at: 0.337 seconds
# Trimming 0.337 seconds from the beginning of 26_rock_90_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1/26_rock_90_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.337s, MIDI note at 0.000s
#    Trimmed exactly 0.337s from the beginning
#
# Processing row 1080:
# /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/27_rock_90_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/27_rock_90_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1 90
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 90
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/27_rock_90_beat_4-4.mid
# Using provided BPM: 90 (tempo: 666666 μs/beat)
# First MIDI note event at: 0.301 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/27_rock_90_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 26
# First significant audio onset at: 0.302 seconds
# Trimming 0.000 seconds from the beginning of 27_rock_90_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1/27_rock_90_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.302s, MIDI note at 0.301s
#    Trimmed exactly 0.000s from the beginning
#
# Processing row 1081:
# /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/28_rock_90_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/28_rock_90_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1 90
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 90
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/28_rock_90_beat_4-4.mid
# Using provided BPM: 90 (tempo: 666666 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/28_rock_90_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 28
# First significant audio onset at: 0.325 seconds
# Trimming 0.325 seconds from the beginning of 28_rock_90_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1/28_rock_90_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.325s, MIDI note at 0.000s
#    Trimmed exactly 0.325s from the beginning
#
# Processing row 1082:
# /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/29_rock_90_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/29_rock_90_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1 90
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 90
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/29_rock_90_beat_4-4.mid
# Using provided BPM: 90 (tempo: 666666 μs/beat)
# First MIDI note event at: 0.278 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/29_rock_90_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 25
# First significant audio onset at: 0.290 seconds
# Trimming 0.012 seconds from the beginning of 29_rock_90_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1/29_rock_90_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.290s, MIDI note at 0.278s
#    Trimmed exactly 0.012s from the beginning
#
# Processing row 1083:
# /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/3_rock_100_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/3_rock_100_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1 100
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 100
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/3_rock_100_beat_4-4.mid
# Using provided BPM: 100 (tempo: 600000 μs/beat)
# First MIDI note event at: 1.779 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/3_rock_100_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 154
# First significant audio onset at: 1.788 seconds
# Trimming 0.009 seconds from the beginning of 3_rock_100_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1/3_rock_100_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 1.788s, MIDI note at 1.779s
#    Trimmed exactly 0.009s from the beginning
#
# Processing row 1084:
# /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/30_rock_90_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/30_rock_90_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1 90
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 90
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/30_rock_90_beat_4-4.mid
# Using provided BPM: 90 (tempo: 666666 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/30_rock_90_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 28
# First significant audio onset at: 0.325 seconds
# Trimming 0.325 seconds from the beginning of 30_rock_90_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1/30_rock_90_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.325s, MIDI note at 0.000s
#    Trimmed exactly 0.325s from the beginning
#
# Processing row 1085:
# /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/4_rock_100_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/4_rock_100_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1 100
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 100
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/4_rock_100_beat_4-4.mid
# Using provided BPM: 100 (tempo: 600000 μs/beat)
# First MIDI note event at: 0.016 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/4_rock_100_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 3
# First significant audio onset at: 0.035 seconds
# Trimming 0.019 seconds from the beginning of 4_rock_100_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1/4_rock_100_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.035s, MIDI note at 0.016s
#    Trimmed exactly 0.019s from the beginning
#
# Processing row 1086:
# /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/5_rock_100_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/5_rock_100_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1 100
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 100
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/5_rock_100_beat_4-4.mid
# Using provided BPM: 100 (tempo: 600000 μs/beat)
# First MIDI note event at: 0.009 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/5_rock_100_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 3
# First significant audio onset at: 0.035 seconds
# Trimming 0.026 seconds from the beginning of 5_rock_100_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1/5_rock_100_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.035s, MIDI note at 0.009s
#    Trimmed exactly 0.026s from the beginning
#
# Processing row 1087:
# /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/6_rock_100_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/6_rock_100_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1 100
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 100
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/6_rock_100_beat_4-4.mid
# Using provided BPM: 100 (tempo: 600000 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/6_rock_100_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 52
# First significant audio onset at: 0.604 seconds
# Trimming 0.604 seconds from the beginning of 6_rock_100_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1/6_rock_100_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.604s, MIDI note at 0.000s
#    Trimmed exactly 0.604s from the beginning
#
# Processing row 1088:
# /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/7_rock_100_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/7_rock_100_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1 100
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 100
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/7_rock_100_beat_4-4.mid
# Using provided BPM: 100 (tempo: 600000 μs/beat)
# First MIDI note event at: 0.021 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/7_rock_100_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 3
# First significant audio onset at: 0.035 seconds
# Trimming 0.014 seconds from the beginning of 7_rock_100_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1/7_rock_100_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.035s, MIDI note at 0.021s
#    Trimmed exactly 0.014s from the beginning
#
# Processing row 1089:
# /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/8_rock_100_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/8_rock_100_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1 100
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 100
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/8_rock_100_beat_4-4.mid
# Using provided BPM: 100 (tempo: 600000 μs/beat)
# First MIDI note event at: 0.000 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/8_rock_100_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 50
# First significant audio onset at: 0.580 seconds
# Trimming 0.580 seconds from the beginning of 8_rock_100_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1/8_rock_100_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.580s, MIDI note at 0.000s
#    Trimmed exactly 0.580s from the beginning
#
# Processing row 1090:
# /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/9_rock_100_beat_4-4.mid /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/9_rock_100_beat_4-4.wav /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1 100
#
# ==== Precise MIDI-WAV Alignment ====
# Using custom BPM: 100
# Using detection method: fixed (sensitivity: 0.2)
# Analyzing MIDI file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/9_rock_100_beat_4-4.mid
# Using provided BPM: 100 (tempo: 600000 μs/beat)
# First MIDI note event at: 0.010 seconds
# Analyzing WAV file: /Users/danielmartinezvillegas/Downloads/groove/drummer9/session1/9_rock_100_beat_4-4.wav using 'fixed' method (sensitivity: 0.2)
# Fixed onset detection found onset at frame 3
# First significant audio onset at: 0.035 seconds
# Trimming 0.025 seconds from the beginning of 9_rock_100_beat_4-4.wav
# Saved trimmed file to /Users/danielmartinezvillegas/Downloads/groove-aligned/drummer9/session1/9_rock_100_beat_4-4.wav
#
# ✅ Successfully aligned WAV to MIDI
#    WAV onset was at 0.035s, MIDI note at 0.010s
#    Trimmed exactly 0.025s from the beginning
